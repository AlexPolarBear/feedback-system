# %%
import os, sys
print(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.getcwd()))
print(os.path.join(os.path.dirname(os.getcwd()), "model_text_to_tags", "chatGPT"))
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), "model_text_to_tags", "chatGPT"))

from rankingSystem import RankingSystem
# Out:
# c:\Users\nalex\Desktop\different\feedback-system\ranking\ranking_system
# c:\Users\nalex\Desktop\different\feedback-system\ranking\ranking_system\model_text_to_tags\chatGPT

# %%
import pprint

# %%
rk = RankingSystem()

# %%
courses = rk._get_all_courses()

# %%
pprint.pprint(courses)
# Out:
# {'AlgGrS': Course(short_name='AlgGrS',
#                   description='Context already ready!',
#                   id=None,
#                   field_of_knowledge=None,
#                   full_name=None,
#                   size=None,
#                   lecturer_id=None,
#                   year=None,
#                   context=Context(context={'Борелевские подгруппы': Tag(id=-1,
#                                                                         title='Борелевские '
#                                                                               'подгруппы',
#                                                                         type=-1),
#                                            'алгебраические группы': Tag(id=-1,
#                                                                         title='алгебраические '
#                                                                               'группы',
#                                                                         type=-1),
#                                            'алгебры Хопфа': Tag(id=-1,
#                                                                 title='алгебры '
#                                                                       'Хопфа',
#                                                                 type=-1),
#                                            'гладкость': Tag(id=-1,
#                                                             title='гладкость',
#                                                             type=-1),
#                                            'действие': Tag(id=-1,
#                                                            title='действие',
#                                                            type=-1),
#                                            'классификация': Tag(id=-1,
#                                                                 title='классификация',
#                                                                 type=-1),
#                                            'корневые данные': Tag(id=-1,
#                                                                   title='корневые '
#                                                                         'данные',
#                                                                   type=-1),
#                                            'мультипликативный тип': Tag(id=-1,
#                                                                         title='мультипликативный '
#                                                                               'тип',
#                                                                         type=-1),
#                                            'неаффинные группы': Tag(id=-1,
#                                                                     title='неаффинные '
#                                                                           'группы',
#                                                                     type=-1),
#                                            'нильпотентные группы': Tag(id=-1,
#                                                                        title='нильпотентные '
#                                                                              'группы',
#                                                                        type=-1),
#                                            'параболические подгруппы': Tag(id=-1,
#                                                                            title='параболические '
#                                                                                  'подгруппы',
#                                                                            type=-1),
#                                            'пучки': Tag(id=-1,
#                                                         title='пучки',
#                                                         type=-1),
#                                            'разрешимые группы': Tag(id=-1,
#                                                                     title='разрешимые '
#                                                                           'группы',
#                                                                     type=-1),
#                                            'редуктивные группы': Tag(id=-1,
#                                                                      title='редуктивные '
#                                                                            'группы',
#                                                                      type=-1),
#                                            'связность': Tag(id=-1,
#                                                             title='связность',
#                                                             type=-1),
#                                            'схемы Шевалле-Демазюра': Tag(id=-1,
#                                                                          title='схемы '
#                                                                                'Шевалле-Демазюра',
#                                                                          type=-1),
#                                            'унипотентные группы': Tag(id=-1,
#                                                                       title='унипотентные '
#                                                                             'группы',
#                                                                       type=-1),
#                                            'факторизация': Tag(id=-1,
#                                                                title='факторизация',
#                                                                type=-1)})),
#  'CommAlg': Course(short_name='CommAlg',
#                    description='Context already ready!',
#                    id=None,
#                    field_of_knowledge=None,
#                    full_name=None,
#                    size=None,
#                    lecturer_id=None,
#                    year=None,
#                    context=Context(context={'алгебра': Tag(id=-1,
#                                                            title='алгебра',
#                                                            type=-1),
#                                             'алгебраическая геометрия': Tag(id=-1,
#                                                                             title='алгебраическая '
#                                                                                   'геометрия',
#                                                                             type=-1),
#                                             'алгебраическая теория чисел': Tag(id=-1,
#                                                                                title='алгебраическая '
#                                                                                      'теория '
#                                                                                      'чисел',
#                                                                                type=-1),
#                                             'геометрические объекты': Tag(id=-1,
#                                                                           title='геометрические '
#                                                                                 'объекты',
#                                                                           type=-1),
#                                             'дедекиндовы кольца': Tag(id=-1,
#                                                                       title='дедекиндовы '
#                                                                             'кольца',
#                                                                       type=-1),
#                                             'коммутативные кольца': Tag(id=-1,
#                                                                         title='коммутативные '
#                                                                               'кольца',
#                                                                         type=-1),
#                                             'лемма Нетер о нормализации': Tag(id=-1,
#                                                                               title='лемма '
#                                                                                     'Нетер '
#                                                                                     'о '
#                                                                                     'нормализации',
#                                                                               type=-1),
#                                             'локализация': Tag(id=-1,
#                                                                title='локализация',
#                                                                type=-1),
#                                             'нормализация': Tag(id=-1,
#                                                                 title='нормализация',
#                                                                 type=-1),
#                                             'пополнение': Tag(id=-1,
#                                                               title='пополнение',
#                                                               type=-1),
#                                             'размерность': Tag(id=-1,
#                                                                title='размерность',
#                                                                type=-1),
#                                             'структурная теорема Коэна': Tag(id=-1,
#                                                                              title='структурная '
#                                                                                    'теорема '
#                                                                                    'Коэна',
#                                                                              type=-1),
#                                             'теорема Гильберта о нулях': Tag(id=-1,
#                                                                              title='теорема '
#                                                                                    'Гильберта '
#                                                                                    'о '
#                                                                                    'нулях',
#                                                                              type=-1),
#                                             'теория размерности Крулля': Tag(id=-1,
#                                                                              title='теория '
#                                                                                    'размерности '
#                                                                                    'Крулля',
#                                                                              type=-1),
#                                             'топология Зариского': Tag(id=-1,
#                                                                        title='топология '
#                                                                              'Зариского',
#                                                                        type=-1)})),
#  'CommAlg2': Course(short_name='CommAlg2',
#                     description='Context already ready!',
#                     id=None,
#                     field_of_knowledge=None,
#                     full_name=None,
#                     size=None,
#                     lecturer_id=None,
#                     year=None,
#                     context=Context(context={'Барсотти-Шевалле': Tag(id=-1,
#                                                                      title='Барсотти-Шевалле',
#                                                                      type=-1),
#                                              'алгебра Ли': Tag(id=-1,
#                                                                title='алгебра '
#                                                                      'Ли',
#                                                                type=-1),
#                                              'алгебраические группы': Tag(id=-1,
#                                                                           title='алгебраические '
#                                                                                 'группы',
#                                                                           type=-1),
#                                              'алгебры Хопфа': Tag(id=-1,
#                                                                   title='алгебры '
#                                                                         'Хопфа',
#                                                                   type=-1),
#                                              'библиография': Tag(id=-1,
#                                                                  title='библиография',
#                                                                  type=-1),
#                                              'борелевские подгруппы': Tag(id=-1,
#                                                                           title='борелевские '
#                                                                                 'подгруппы',
#                                                                           type=-1),
#                                              'гладкость': Tag(id=-1,
#                                                               title='гладкость',
#                                                               type=-1),
#                                              'гомоморфизмы': Tag(id=-1,
#                                                                  title='гомоморфизмы',
#                                                                  type=-1),
#                                              'двойственность Картье': Tag(id=-1,
#                                                                           title='двойственность '
#                                                                                 'Картье',
#                                                                           type=-1),
#                                              'действие': Tag(id=-1,
#                                                              title='действие',
#                                                              type=-1),
#                                              'замкнутая орбита': Tag(id=-1,
#                                                                      title='замкнутая '
#                                                                            'орбита',
#                                                                      type=-1),
#                                              'классификация': Tag(id=-1,
#                                                                   title='классификация',
#                                                                   type=-1),
#                                              'конечные группы': Tag(id=-1,
#                                                                     title='конечные '
#                                                                           'группы',
#                                                                     type=-1),
#                                              'корневые данные': Tag(id=-1,
#                                                                     title='корневые '
#                                                                           'данные',
#                                                                     type=-1),
#                                              'линейные представления': Tag(id=-1,
#                                                                            title='линейные '
#                                                                                  'представления',
#                                                                            type=-1),
#                                              'мультипликативный тип': Tag(id=-1,
#                                                                           title='мультипликативный '
#                                                                                 'тип',
#                                                                           type=-1),
#                                              'неаффинные алгебраические группы': Tag(id=-1,
#                                                                                      title='неаффинные '
#                                                                                            'алгебраические '
#                                                                                            'группы',
#                                                                                      type=-1),
#                                              'нильпотентные группы': Tag(id=-1,
#                                                                          title='нильпотентные '
#                                                                                'группы',
#                                                                          type=-1),
#                                              'параболические подгруппы': Tag(id=-1,
#                                                                              title='параболические '
#                                                                                    'подгруппы',
#                                                                              type=-1),
#                                              'подгруппы': Tag(id=-1,
#                                                               title='подгруппы',
#                                                               type=-1),
#                                              'простые алгебраические группы': Tag(id=-1,
#                                                                                   title='простые '
#                                                                                         'алгебраические '
#                                                                                         'группы',
#                                                                                   type=-1),
#                                              'пучки': Tag(id=-1,
#                                                           title='пучки',
#                                                           type=-1),
#                                              'разложение Жордана': Tag(id=-1,
#                                                                        title='разложение '
#                                                                              'Жордана',
#                                                                        type=-1),
#                                              'разрешимые группы': Tag(id=-1,
#                                                                       title='разрешимые '
#                                                                             'группы',
#                                                                       type=-1),
#                                              'редуктивные группы': Tag(id=-1,
#                                                                        title='редуктивные '
#                                                                              'группы',
#                                                                        type=-1),
#                                              'связность': Tag(id=-1,
#                                                               title='связность',
#                                                               type=-1),
#                                              'строго плоские морфизмы': Tag(id=-1,
#                                                                             title='строго '
#                                                                                   'плоские '
#                                                                                   'морфизмы',
#                                                                             type=-1),
#                                              'схемы Шевалле-Демазюра': Tag(id=-1,
#                                                                            title='схемы '
#                                                                                  'Шевалле-Демазюра',
#                                                                            type=-1),
#                                              'унипотентные группы': Tag(id=-1,
#                                                                         title='унипотентные '
#                                                                               'группы',
#                                                                         type=-1),
#                                              'факторизация': Tag(id=-1,
#                                                                  title='факторизация',
#                                                                  type=-1)})),
#  'DeepLearn': Course(short_name='DeepLearn',
#                      description='Context already ready!',
#                      id=None,
#                      field_of_knowledge=None,
#                      full_name=None,
#                      size=None,
#                      lecturer_id=None,
#                      year=None,
#                      context=Context(context={'глубокое обучение': Tag(id=-1,
#                                                                        title='глубокое '
#                                                                              'обучение',
#                                                                        type=-1),
#                                               'компьютерное зрение': Tag(id=-1,
#                                                                          title='компьютерное '
#                                                                                'зрение',
#                                                                          type=-1),
#                                               'машинное обучение': Tag(id=-1,
#                                                                        title='машинное '
#                                                                              'обучение',
#                                                                        type=-1),
#                                               'нейронные сети': Tag(id=-1,
#                                                                     title='нейронные '
#                                                                           'сети',
#                                                                     type=-1),
#                                               'обработка естественного языка': Tag(id=-1,
#                                                                                    title='обработка '
#                                                                                          'естественного '
#                                                                                          'языка',
#                                                                                    type=-1),
#                                               'распознавание речи': Tag(id=-1,
#                                                                         title='распознавание '
#                                                                               'речи',
#                                                                         type=-1)})),
#  'VarCalc': Course(short_name='VarCalc',
#                    description='Context already ready!',
#                    id=None,
#                    field_of_knowledge=None,
#                    full_name=None,
#                    size=None,
#                    lecturer_id=None,
#                    year=None,
#                    context=Context(context={'вариационное исчисление': Tag(id=-1,
#                                                                            title='вариационное '
#                                                                                  'исчисление',
#                                                                            type=-1),
#                                             'краевые задачи': Tag(id=-1,
#                                                                   title='краевые '
#                                                                         'задачи',
#                                                                   type=-1),
#                                             'метод Нехари': Tag(id=-1,
#                                                                 title='метод '
#                                                                       'Нехари',
#                                                                 type=-1),
#                                             'метод движущихся плоскостей': Tag(id=-1,
#                                                                                title='метод '
#                                                                                      'движущихся '
#                                                                                      'плоскостей',
#                                                                                type=-1),
#                                             'неравенство Пойа-Сеге': Tag(id=-1,
#                                                                          title='неравенство '
#                                                                                'Пойа-Сеге',
#                                                                          type=-1),
#                                             'неравенство Рисса': Tag(id=-1,
#                                                                      title='неравенство '
#                                                                            'Рисса',
#                                                                      type=-1),
#                                             'принцип Лионса': Tag(id=-1,
#                                                                   title='принцип '
#                                                                         'Лионса',
#                                                                   type=-1),
#                                             'пространства Соболева': Tag(id=-1,
#                                                                          title='пространства '
#                                                                                'Соболева',
#                                                                          type=-1),
#                                             'существование минимума': Tag(id=-1,
#                                                                           title='существование '
#                                                                                 'минимума',
#                                                                           type=-1),
#                                             'тождество Похожаева': Tag(id=-1,
#                                                                        title='тождество '
#                                                                              'Похожаева',
#                                                                        type=-1),
#                                             'уравнения в частных производных': Tag(id=-1,
#                                                                                    title='уравнения '
#                                                                                          'в '
#                                                                                          'частных '
#                                                                                          'производных',
#                                                                                    type=-1)}))}
