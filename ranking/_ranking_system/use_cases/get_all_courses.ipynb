# %%
import os, sys
print(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.getcwd()))
print(os.path.join(os.path.dirname(os.getcwd()), "model_text_to_tags", "chatGPT"))
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), "model_text_to_tags", "chatGPT"))

from rankingSystem import RankingSystem
# Out:
# c:\Users\nalex\Desktop\different\feedback-system\ranking\ranking_system
# c:\Users\nalex\Desktop\different\feedback-system\ranking\ranking_system\model_text_to_tags\chatGPT

# %%
import pprint

# %%
rk = RankingSystem()

# %%
courses = rk._get_all_courses()

# %%
pprint.pprint(courses)
# Out:
# {'AlgGrS': Course(short_name='AlgGrS',
#                   description='Context already ready!',
#                   id=None,
#                   field_of_knowledge=None,
#                   full_name=None,
#                   size=None,
#                   lecturer_id=None,
#                   year=None,
#                   context={'абелевы многообразия': {'id': -1,
#                                                     'title': 'абелевы '
#                                                              'многообразия',
#                                                     'type': -1},
#                            'алгебра Хопфа': {'id': -1,
#                                              'title': 'алгебра Хопфа',
#                                              'type': -1},
#                            'алгебраические многообразия': {'id': -1,
#                                                            'title': 'алгебраические '
#                                                                     'многообразия',
#                                                            'type': -1},
#                            'алгебраические торы': {'id': -1,
#                                                    'title': 'алгебраические '
#                                                             'торы',
#                                                    'type': -1},
#                            'борелевские подгруппы': {'id': -1,
#                                                      'title': 'борелевские '
#                                                               'подгруппы',
#                                                      'type': -1},
#                            'гладкость': {'id': -1,
#                                          'title': 'гладкость',
#                                          'type': -1},
#                            'групповые структуры': {'id': -1,
#                                                    'title': 'групповые '
#                                                             'структуры',
#                                                    'type': -1},
#                            'группы мультипликативного типа': {'id': -1,
#                                                               'title': 'группы '
#                                                                        'мультипликативного '
#                                                                        'типа',
#                                                               'type': -1},
#                            'двойственность Картье': {'id': -1,
#                                                      'title': 'двойственность '
#                                                               'Картье',
#                                                      'type': -1},
#                            'действие алгебраических групп': {'id': -1,
#                                                              'title': 'действие '
#                                                                       'алгебраических '
#                                                                       'групп',
#                                                              'type': -1},
#                            'классификация простых алгебраических групп': {'id': -1,
#                                                                           'title': 'классификация '
#                                                                                    'простых '
#                                                                                    'алгебраических '
#                                                                                    'групп',
#                                                                           'type': -1},
#                            'конечные группы как алгебраические': {'id': -1,
#                                                                   'title': 'конечные '
#                                                                            'группы '
#                                                                            'как '
#                                                                            'алгебраические',
#                                                                   'type': -1},
#                            'корневые данные': {'id': -1,
#                                                'title': 'корневые данные',
#                                                'type': -1},
#                            'лемма о замкнутой орбите': {'id': -1,
#                                                         'title': 'лемма о '
#                                                                  'замкнутой '
#                                                                  'орбите',
#                                                         'type': -1},
#                            'линейные представления': {'id': -1,
#                                                       'title': 'линейные '
#                                                                'представления',
#                                                       'type': -1},
#                            'неаффинные алгебраические группы': {'id': -1,
#                                                                 'title': 'неаффинные '
#                                                                          'алгебраические '
#                                                                          'группы',
#                                                                 'type': -1},
#                            'нильпотентные группы': {'id': -1,
#                                                     'title': 'нильпотентные '
#                                                              'группы',
#                                                     'type': -1},
#                            'ортогональная группа': {'id': -1,
#                                                     'title': 'ортогональная '
#                                                              'группа',
#                                                     'type': -1},
#                            'основные понятия алгебраических групп': {'id': -1,
#                                                                      'title': 'основные '
#                                                                               'понятия '
#                                                                               'алгебраических '
#                                                                               'групп',
#                                                                      'type': -1},
#                            'параболические подгруппы': {'id': -1,
#                                                         'title': 'параболические '
#                                                                  'подгруппы',
#                                                         'type': -1},
#                            'полная линейная группа': {'id': -1,
#                                                       'title': 'полная '
#                                                                'линейная '
#                                                                'группа',
#                                                       'type': -1},
#                            'разложение Жордана': {'id': -1,
#                                                   'title': 'разложение Жордана',
#                                                   'type': -1},
#                            'разрешимые группы': {'id': -1,
#                                                  'title': 'разрешимые группы',
#                                                  'type': -1},
#                            'связность': {'id': -1,
#                                          'title': 'связность',
#                                          'type': -1},
#                            'строго плоские морфизмы': {'id': -1,
#                                                        'title': 'строго '
#                                                                 'плоские '
#                                                                 'морфизмы',
#                                                        'type': -1},
#                            'схемы Шевалле-Демазюра': {'id': -1,
#                                                       'title': 'схемы '
#                                                                'Шевалле-Демазюра',
#                                                       'type': -1},
#                            'теорема Барсотти-Шевалле': {'id': -1,
#                                                         'title': 'теорема '
#                                                                  'Барсотти-Шевалле',
#                                                         'type': -1},
#                            'теоремы общей теории алгебраических групп': {'id': -1,
#                                                                          'title': 'теоремы '
#                                                                                   'общей '
#                                                                                   'теории '
#                                                                                   'алгебраических '
#                                                                                   'групп',
#                                                                          'type': -1},
#                            'унипотентные группы': {'id': -1,
#                                                    'title': 'унипотентные '
#                                                             'группы',
#                                                    'type': -1},
#                            'факторизация': {'id': -1,
#                                             'title': 'факторизация',
#                                             'type': -1}}),
#  'CommAlg': Course(short_name='CommAlg',
#                    description='Context already ready!',
#                    id=None,
#                    field_of_knowledge=None,
#                    full_name=None,
#                    size=None,
#                    lecturer_id=None,
#                    year=None,
#                    context={'Лемма Нетер о нормализации': {'id': -1,
#                                                            'title': 'Лемма '
#                                                                     'Нетер о '
#                                                                     'нормализации',
#                                                            'type': -1},
#                             'Структурная теорема Коэна': {'id': -1,
#                                                           'title': 'Структурная '
#                                                                    'теорема '
#                                                                    'Коэна',
#                                                           'type': -1},
#                             'алгебраическая геометрия': {'id': -1,
#                                                          'title': 'алгебраическая '
#                                                                   'геометрия',
#                                                          'type': -1},
#                             'алгебраическая теория чисел': {'id': -1,
#                                                             'title': 'алгебраическая '
#                                                                      'теория '
#                                                                      'чисел',
#                                                             'type': -1},
#                             'дедекиндовы кольца': {'id': -1,
#                                                    'title': 'дедекиндовы '
#                                                             'кольца',
#                                                    'type': -1},
#                             'коммутативные кольца': {'id': -1,
#                                                      'title': 'коммутативные '
#                                                               'кольца',
#                                                      'type': -1},
#                             'литература': {'id': -1,
#                                            'title': 'литература',
#                                            'type': -1},
#                             'локализация': {'id': -1,
#                                             'title': 'локализация',
#                                             'type': -1},
#                             'локальная алгебраическая геометрия': {'id': -1,
#                                                                    'title': 'локальная '
#                                                                             'алгебраическая '
#                                                                             'геометрия',
#                                                                    'type': -1},
#                             'нормализация': {'id': -1,
#                                              'title': 'нормализация',
#                                              'type': -1},
#                             'пополнение': {'id': -1,
#                                            'title': 'пополнение',
#                                            'type': -1},
#                             'структура': {'id': -1,
#                                           'title': 'структура',
#                                           'type': -1},
#                             'теорема Гильберта о нулях': {'id': -1,
#                                                           'title': 'теорема '
#                                                                    'Гильберта '
#                                                                    'о нулях',
#                                                           'type': -1},
#                             'теория размерности Крулля': {'id': -1,
#                                                           'title': 'теория '
#                                                                    'размерности '
#                                                                    'Крулля',
#                                                           'type': -1},
#                             'топология Зариского': {'id': -1,
#                                                     'title': 'топология '
#                                                              'Зариского',
#                                                     'type': -1}}),
#  'CommAlg2': Course(short_name='CommAlg2',
#                     description='Context already ready!',
#                     id=None,
#                     field_of_knowledge=None,
#                     full_name=None,
#                     size=None,
#                     lecturer_id=None,
#                     year=None,
#                     context={'Борелевские подгруппы': {'id': -1,
#                                                        'title': 'Борелевские '
#                                                                 'подгруппы',
#                                                        'type': -1},
#                              'алгебра Ли': {'id': -1,
#                                             'title': 'алгебра Ли',
#                                             'type': -1},
#                              'алгебраические группы': {'id': -1,
#                                                        'title': 'алгебраические '
#                                                                 'группы',
#                                                        'type': -1},
#                              'гладкость': {'id': -1,
#                                            'title': 'гладкость',
#                                            'type': -1},
#                              'действие группы': {'id': -1,
#                                                  'title': 'действие группы',
#                                                  'type': -1},
#                              'корневые данные': {'id': -1,
#                                                  'title': 'корневые данные',
#                                                  'type': -1},
#                              'линейные представления': {'id': -1,
#                                                         'title': 'линейные '
#                                                                  'представления',
#                                                         'type': -1},
#                              'мультипликативный тип': {'id': -1,
#                                                        'title': 'мультипликативный '
#                                                                 'тип',
#                                                        'type': -1},
#                              'неаффинные группы': {'id': -1,
#                                                    'title': 'неаффинные группы',
#                                                    'type': -1},
#                              'нильпотентные группы': {'id': -1,
#                                                       'title': 'нильпотентные '
#                                                                'группы',
#                                                       'type': -1},
#                              'параболические подгруппы': {'id': -1,
#                                                           'title': 'параболические '
#                                                                    'подгруппы',
#                                                           'type': -1},
#                              'простые группы': {'id': -1,
#                                                 'title': 'простые группы',
#                                                 'type': -1},
#                              'пучки': {'id': -1, 'title': 'пучки', 'type': -1},
#                              'разрешимые группы': {'id': -1,
#                                                    'title': 'разрешимые группы',
#                                                    'type': -1},
#                              'редуктивные группы': {'id': -1,
#                                                     'title': 'редуктивные '
#                                                              'группы',
#                                                     'type': -1},
#                              'связность': {'id': -1,
#                                            'title': 'связность',
#                                            'type': -1},
#                              'схемы Шевалле-Демазюра': {'id': -1,
#                                                         'title': 'схемы '
#                                                                  'Шевалле-Демазюра',
#                                                         'type': -1},
#                              'унипотентные группы': {'id': -1,
#                                                      'title': 'унипотентные '
#                                                               'группы',
#                                                      'type': -1},
#                              'факторизация групп': {'id': -1,
#                                                     'title': 'факторизация '
#                                                              'групп',
#                                                     'type': -1}}),
#  'DeepLearn': Course(short_name='DeepLearn',
#                      description='Context already ready!',
#                      id=None,
#                      field_of_knowledge=None,
#                      full_name=None,
#                      size=None,
#                      lecturer_id=None,
#                      year=None,
#                      context={'глубокое обучение': {'id': -1,
#                                                     'title': 'глубокое '
#                                                              'обучение',
#                                                     'type': -1},
#                               'компьютерное зрение': {'id': -1,
#                                                       'title': 'компьютерное '
#                                                                'зрение',
#                                                       'type': -1},
#                               'машинное обучение': {'id': -1,
#                                                     'title': 'машинное '
#                                                              'обучение',
#                                                     'type': -1},
#                               'нейронные сети': {'id': -1,
#                                                  'title': 'нейронные сети',
#                                                  'type': -1},
#                               'обработка естественного языка': {'id': -1,
#                                                                 'title': 'обработка '
#                                                                          'естественного '
#                                                                          'языка',
#                                                                 'type': -1},
#                               'распознавание речи': {'id': -1,
#                                                      'title': 'распознавание '
#                                                               'речи',
#                                                      'type': -1}}),
#  'HomolAlg': Course(short_name='HomolAlg',
#                     description='Context already ready!',
#                     id=None,
#                     field_of_knowledge=None,
#                     full_name=None,
#                     size=None,
#                     lecturer_id=None,
#                     year=None,
#                     context={'алгебраическая топология': {'id': -1,
#                                                           'title': 'алгебраическая '
#                                                                    'топология',
#                                                           'type': -1},
#                              'гомологии': {'id': -1,
#                                            'title': 'гомологии',
#                                            'type': -1},
#                              'группы гомологий': {'id': -1,
#                                                   'title': 'группы гомологий',
#                                                   'type': -1},
#                              'когомологии': {'id': -1,
#                                              'title': 'когомологии',
#                                              'type': -1},
#                              'сложные объекты': {'id': -1,
#                                                  'title': 'сложные объекты',
#                                                  'type': -1},
#                              'спектральные последовательности': {'id': -1,
#                                                                  'title': 'спектральные '
#                                                                           'последовательности',
#                                                                  'type': -1},
#                              'тензорное произведение': {'id': -1,
#                                                         'title': 'тензорное '
#                                                                  'произведение',
#                                                         'type': -1},
#                              'функтор Ext': {'id': -1,
#                                              'title': 'функтор Ext',
#                                              'type': -1},
#                              'функтор Tor': {'id': -1,
#                                              'title': 'функтор Tor',
#                                              'type': -1}}),
#  'VarCalc': Course(short_name='VarCalc',
#                    description='Context already ready!',
#                    id=None,
#                    field_of_knowledge=None,
#                    full_name=None,
#                    size=None,
#                    lecturer_id=None,
#                    year=None,
#                    context={'вариационное исчисление': {'id': -1,
#                                                         'title': 'вариационное '
#                                                                  'исчисление',
#                                                         'type': -1},
#                             'краевые задачи': {'id': -1,
#                                                'title': 'краевые задачи',
#                                                'type': -1},
#                             'метод Нехари': {'id': -1,
#                                              'title': 'метод Нехари',
#                                              'type': -1},
#                             'метод движущихся плоскостей': {'id': -1,
#                                                             'title': 'метод '
#                                                                      'движущихся '
#                                                                      'плоскостей',
#                                                             'type': -1},
#                             'неравенство Пойа-Сеге': {'id': -1,
#                                                       'title': 'неравенство '
#                                                                'Пойа-Сеге',
#                                                       'type': -1},
#                             'неравенство Рисса': {'id': -1,
#                                                   'title': 'неравенство Рисса',
#                                                   'type': -1},
#                             'принцип Лионса': {'id': -1,
#                                                'title': 'принцип Лионса',
#                                                'type': -1},
#                             'пространства Соболева': {'id': -1,
#                                                       'title': 'пространства '
#                                                                'Соболева',
#                                                       'type': -1},
#                             'существование минимума': {'id': -1,
#                                                        'title': 'существование '
#                                                                 'минимума',
#                                                        'type': -1},
#                             'тождество Похожаева': {'id': -1,
#                                                     'title': 'тождество '
#                                                              'Похожаева',
#                                                     'type': -1},
#                             'уравнения в частных производных': {'id': -1,
#                                                                 'title': 'уравнения '
#                                                                          'в '
#                                                                          'частных '
#                                                                          'производных',
#                                                                 'type': -1}})}
